# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
score = [45,55,87,55,44,58,98,54,78,53,68,96,
        54,78,98,65,33,87,54,87,55,85,58,54,57,
        40,65,52,44,66,40,98,54,57,41,25,68,58]

df = pd.DataFrame({'Score' : score})
df.head()
# Out:
#    Score
# 0     45
# 1     55
# 2     87
# 3     55
# 4     44

# %%
df.describe()
# Out:
#            Score
# count  38.000000
# mean   62.210526
# std    19.006625
# min    25.000000
# 25%    53.250000
# 50%    57.000000
# 75%    75.500000
# max    98.000000

# %%
mean_val = df['Score'].mean()
std_val = df['Score'].std()
count_val = df['Score'].count()
min_val = df['Score'].min()
max_val = df['Score'].max()
mode_val = df['Score'].mode()
median_val = df['Score'].median()

print('mode :' ,mode_val)
print('median :' ,median_val)
print('count :', count_val)
print('mn :' ,min_val)
print('mx :',max_val)
print( 'std :' ,std_val)
print(  'mean :' ,mean_val)
# Out:
# mode : 0    54
# Name: Score, dtype: int64
# median : 57.0
# count : 38
# mn : 25
# mx : 98
# std : 19.006624584441166
# mean : 62.21052631578947

# %%
bins = [39,49,59,69,79,89,100]
labels = ['40-49','50-59','60-69','70-79','80-89','90-100']
df['Grade'] = pd.cut(df['Score'],bins=bins,labels=labels)

fre_table = df["Grade"].value_counts().sort_index()

print(fre_table)
# Out:
# Grade
# 40-49      6
# 50-59     15
# 60-69      5
# 70-79      2
# 80-89      4
# 90-100     4
# Name: count, dtype: int64

# %%
df['Score'].plot(kind='hist',bins=[39,49,59,69,79,89,100],edgecolor ='black')
plt.xlabel('Score')
plt.title('Histogram of Exam score')
plt.show()
